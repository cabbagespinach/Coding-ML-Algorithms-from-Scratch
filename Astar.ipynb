# %%
import os
import pandas as pd
file_path = './astar_in.txt'
data = pd.read_csv(file_path)

with open(file_path, 'r') as file:
    lines = [l.strip() for l in file.readlines() if len(l.split(' ')) == 3]
    start_list = ' '.join([l for l in lines[:3]]).split(' ')
    start_state = [l.split(' ') for l in lines[:3]]
    end_state = [l.split(' ') for l in lines[3:]]
# Out:
# C:\Users\Arvir\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Arvir\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
def display_node(node):
    for i in range(len(node)):
        print(node[i])

# %% [markdown]
# ### Guide Pseudocode
#
# - Put the start node in the OPEN list
# - Check if the current node is already in the CLOSED list
#     - If yes, compare the score of the current node vs the node in the closed list
#         - If the node in the CLOSED list is lower, use that path
#         - If the node in the CLOSED list is higher, exit and choose the next node in the OPEN list
# - Check if the start/current node is the goal state
#     - If yes, return the solution
#     - Otherwise, add the node in the CLOSED list and continue with next step
# - Add the current node to the CLOSED list
# - Generate the list of expansion states from the start/current node
#     - Insert the list in the OPEN list
# - Compute the function by adding the ff:
#     - The path cost from the start node to each of the expanded states
#     - The manhattan distance of each expanded state to the goal state
# - The node with the lowest function score becomes the current node

# %%
display_node(start_state)
# Out:
# ['2', '1', '6']
# ['4', '*', '8']
# ['7', '5', '3']

# %%
display_node(end_state)
# Out:
# ['1', '2', '3']
# ['8', '*', '4']
# ['7', '6', '5']

# %%
import copy

def manhattan_calculator(start_state, end_state):
    manhattan_distance = 0
            
    for list1 in start_state:
        
        for item in list1:
            
            x1 = list1.index(item)
            y1 = start_state.index(list1)
            
            for list2 in end_state:
                
                if item in list2:
                    x2 = list2.index(item)
                    y2 = end_state.index(list2)
                    manhattan_distance += abs(x2-x1) + abs(y2-y1)
    
    return manhattan_distance

def no_of_wrong_tiles_calculator(node, end_state):
    
    no_of_wrong_tiles = 0
    
    l = 0
    for list_ in node:
        i = 0
        for item in list_:
            if node[l][i] != '*' and node[l][i] != end_state[l][i]:
                no_of_wrong_tiles += 1
            i += 1
        l += 1
    
    return no_of_wrong_tiles

def get_clockwise_expectation(goal_state):
    end_state_1d = []
    clockwise_order = [0, 1, 2, 7, 8, 3, 6, 5, 4]
    for list in end_state:
        for item in list:
            end_state_1d.append(item)
    end_state_1d_clockwise = []
    num = 0
    end_state_1d_clockwise = copy.deepcopy(end_state_1d)
    for i in clockwise_order:
        end_state_1d_clockwise[i] = end_state_1d[num]
        num += 1

    end_state_1d_clockwise1 = copy.deepcopy(end_state_1d_clockwise)
    end_state_1d_clockwise.remove('*')
    end_state_1d_clockwise1.remove('*')
    end_state_1d_clockwise1.append(end_state_1d_clockwise1[0])
    clockwise_expectation = {}
    num = 0
    for i in end_state_1d_clockwise:
        clockwise_expectation[i] = end_state_1d_clockwise1[num+1]
        num += 1
    return clockwise_expectation

def nilsson_sequence_calculator(node, end_state):
    
    clockwise_expectation = get_clockwise_expectation(end_state)
    manhattan_distance = manhattan_calculator(start_state, end_state)
    sequence_score = 0

    for i in range(len(node)):
        for j in range(len(node)):
            if node[i][j] == '*':
                continue
            elif i == 1 and j == 1:
                sequence_score += 1
            else:
                if i == 0 and j < 2 and node[i][j + 1] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                elif j == 2 and i < 2 and node[i + 1][j] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                elif j > 0 and i == 2 and node[i][j - 1] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                elif i > 0 and j == 0 and node[i - 1][j] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                    
    nilsson_sequence_score = manhattan_distance + 3 * sequence_score
    return sequence_score

def expand_node(node):
    
    expanded_node_list = []
    
    for list in node:
        if list.count('*'):
            x = list.index('*')
            y = node.index(list)
            break
        else:
            continue
            
    x_left = x - 1
    x_right = x + 1
    y_up = y - 1
    y_down = y + 1
            
    if x_left >= 0:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y][x_left]
        new_list[y][x_left] = '*'
        expanded_node_list.append(new_list)
            
    if x_right <= 2:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y][x_right]
        new_list[y][x_right] = '*'
        expanded_node_list.append(new_list)
        
    if y_up >= 0:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y_up][x]
        new_list[y_up][x] = '*'
        expanded_node_list.append(new_list)
        
    if y_down <= 2:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y_down][x]
        new_list[y_down][x] = '*'
        expanded_node_list.append(new_list)
            
    return expanded_node_list

def goal_checker(node, goal_state):
    if node == goal_state: return True
    else: return False
    
def func_score(node, current_path_cost, goal_state, function_name):
    if function_name == 'manhattan distance':
        return current_path_cost + manhattan_calculator(node, goal_state), manhattan_calculator(node, goal_state)
    if function_name == 'nilsson sequence':
        return current_path_cost + manhattan_calculator(node, goal_state) + 3 * nilsson_sequence_calculator(node, goal_state), nilsson_sequence_calculator(node, goal_state), manhattan_calculator(node, goal_state) + 3 * nilsson_sequence_calculator(node, goal_state)
    if function_name == 'wrong tiles':
        return no_of_wrong_tiles_calculator(node, goal_state), no_of_wrong_tiles_calculator(node, goal_state)

# %%
def main_function(start_state, goal_state, function_name):
    
    current_node = copy.deepcopy(start_state)
    prev_node = copy.deepcopy(start_state)
    OPEN = []
    current_solution = []
    correct_solution = []
    CLOSED = []
    CLOSED_info = []
    current_path_cost = 0
    OPEN.append(current_node)
    backtrack = []
    backtrack_scores = []
    
    while len(OPEN) > 0:
        
        CLOSED_dict = {}
            
        if current_node in CLOSED:
            x = func_score(current_node, current_path_cost, goal_state, function_name)[0]
            y = CLOSED_info[CLOSED.index(current_node)].get('score')
            if y < x:
                current_solution = CLOSED_info[CLOSED.index(current_node)].get('sequence')
            else:
                OPEN.remove(current_node)
                if len(OPEN) == 0:
                    backtrack_lowest = backtrack_scores.index(min(backtrack_scores))
                    current_node = backtrack[backtrack_lowest]
                else: current_node = OPEN[0]
        
        if goal_checker(current_node, goal_state):
            correct_solution = current_solution
            return correct_solution, current_path_cost
            
        else:
            CLOSED.append(current_node)
            CLOSED_dict['score'] = func_score(current_node, current_path_cost, goal_state, function_name)[0]
            CLOSED_dict['sequence'] = current_solution
            CLOSED_info.append(CLOSED_dict)
        
        OPEN = expand_node(current_node)
        
        if OPEN.count(prev_node) > 0:
            OPEN.remove(prev_node)
            
        CLOSED.append(current_node)
        CLOSED_dict['score'] = func_score(current_node, current_path_cost, goal_state, function_name)[0]
        CLOSED_dict['sequence'] = current_solution
        CLOSED_info.append(CLOSED_dict)
        
        OPEN_scores = [func_score(i, current_path_cost, goal_state, function_name)[0] for i in OPEN]
        lowest_score_node = OPEN_scores.index(min(OPEN_scores))
        backtrack_scores.extend(OPEN_scores)
        print('f(n) =', min(OPEN_scores), '(Function Score)')
        print('g(n) =', current_path_cost, '(Current Step Cost)')
        
        if function_name == 'nilsson sequence':
            print('p(n) =', func_score(current_node, current_path_cost, goal_state, function_name)[1], '(Manhattan Distance)')
            print('s(n) =', func_score(current_node, current_path_cost, goal_state, function_name)[1], '(Sequence Score)')
            print('h(n) =', func_score(current_node, current_path_cost, goal_state, function_name)[2], '(Nilsson Sequence)')
        
        if function_name == 'manhattan distance':
            print('p(n) =', func_score(current_node, current_path_cost, goal_state, function_name)[1], '(Manhattan Distance)')
            
        if function_name == 'wrong tiles':
            print('m(n) =', func_score(current_node, current_path_cost, goal_state, function_name)[1], '(Wrong Tiles Count)')
            
        print('search cost:', len(CLOSED))
        print('------------------------------')
        prev_node = copy.deepcopy(current_node)
        current_node = OPEN[lowest_score_node]
        backtrack.extend(OPEN)
        backtrack_scores.remove(backtrack_scores[backtrack.index(current_node)])
        backtrack.remove(current_node)
        current_solution.append(current_node)
        current_path_cost += 1

# %%
main_function(start_state, end_state, 'manhattan distance')
# Out:
# f(n) = 12 (Function Score)
# g(n) = 0 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 2
# ------------------------------
# f(n) = 15 (Function Score)
# g(n) = 1 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 4
# ------------------------------
# f(n) = 14 (Function Score)
# g(n) = 2 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# search cost: 6
# ------------------------------
# f(n) = 15 (Function Score)
# g(n) = 3 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 8
# ------------------------------
# f(n) = 16 (Function Score)
# g(n) = 4 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 10
# ------------------------------
# f(n) = 15 (Function Score)
# g(n) = 5 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 12
# ------------------------------
# f(n) = 16 (Function Score)
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 14
# ------------------------------
# f(n) = 19 (Function Score)
# g(n) = 7 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 16
# ------------------------------
# f(n) = 20 (Function Score)
# g(n) = 8 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 18
# ------------------------------
# f(n) = 19 (Function Score)
# g(n) = 9 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 20
# ------------------------------
# f(n) = 22 (Function Score)
# g(n) = 10 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 22
# ------------------------------
# f(n) = 23 (Function Score)
# g(n) = 11 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 24
# ------------------------------
# f(n) = 24 (Function Score)
# g(n) = 12 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 26
# ------------------------------
# f(n) = 23 (Function Score)
# g(n) = 13 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 28
# ------------------------------
# f(n) = 24 (Function Score)
# g(n) = 14 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 30
# ------------------------------
# f(n) = 27 (Function Score)
# g(n) = 15 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 32
# ------------------------------
# f(n) = 26 (Function Score)
# g(n) = 16 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 34
# ------------------------------
# f(n) = 27 (Function Score)
# g(n) = 17 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 36
# ------------------------------
# f(n) = 28 (Function Score)
# g(n) = 18 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 38
# ------------------------------
# f(n) = 29 (Function Score)
# g(n) = 19 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 40
# ------------------------------
# f(n) = 30 (Function Score)
# g(n) = 20 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 42
# ------------------------------
# f(n) = 33 (Function Score)
# g(n) = 21 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 44
# ------------------------------
# f(n) = 32 (Function Score)
# g(n) = 22 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# search cost: 46
# ------------------------------
# f(n) = 31 (Function Score)
# g(n) = 23 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 48
# ------------------------------
# f(n) = 32 (Function Score)
# g(n) = 24 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 50
# ------------------------------
# f(n) = 33 (Function Score)
# g(n) = 25 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 52
# ------------------------------
# f(n) = 34 (Function Score)
# g(n) = 26 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 54
# ------------------------------
# f(n) = 35 (Function Score)
# g(n) = 27 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 56
# ------------------------------
# f(n) = 38 (Function Score)
# g(n) = 28 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 58
# ------------------------------
# f(n) = 39 (Function Score)
# g(n) = 29 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 60
# ------------------------------
# f(n) = 40 (Function Score)
# g(n) = 30 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 62
# ------------------------------
# f(n) = 39 (Function Score)
# g(n) = 31 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 64
# ------------------------------
# f(n) = 42 (Function Score)
# g(n) = 32 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 66
# ------------------------------
# f(n) = 43 (Function Score)
# g(n) = 33 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 68
# ------------------------------
# f(n) = 42 (Function Score)
# g(n) = 34 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 70
# ------------------------------
# f(n) = 43 (Function Score)
# g(n) = 35 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 72
# ------------------------------
# f(n) = 44 (Function Score)
# g(n) = 36 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 74
# ------------------------------
# f(n) = 45 (Function Score)
# g(n) = 37 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 76
# ------------------------------
# f(n) = 46 (Function Score)
# g(n) = 38 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 78
# ------------------------------
# f(n) = 49 (Function Score)
# g(n) = 39 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 80
# ------------------------------
# f(n) = 50 (Function Score)
# g(n) = 40 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 82
# ------------------------------
# f(n) = 51 (Function Score)
# g(n) = 41 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 84
# ------------------------------
# f(n) = 52 (Function Score)
# g(n) = 42 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 86
# ------------------------------
# f(n) = 53 (Function Score)
# g(n) = 43 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 88
# ------------------------------
# f(n) = 54 (Function Score)
# g(n) = 44 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 90
# ------------------------------
# f(n) = 55 (Function Score)
# g(n) = 45 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 92
# ------------------------------
# f(n) = 54 (Function Score)
# g(n) = 46 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# search cost: 94
# ------------------------------
# f(n) = 53 (Function Score)
# g(n) = 47 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 96
# ------------------------------
# f(n) = 56 (Function Score)
# g(n) = 48 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# search cost: 98
# ------------------------------
# f(n) = 57 (Function Score)
# g(n) = 49 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 100
# ------------------------------
# f(n) = 58 (Function Score)
# g(n) = 50 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 102
# ------------------------------
# f(n) = 59 (Function Score)
# g(n) = 51 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 104
# ------------------------------
# f(n) = 60 (Function Score)
# g(n) = 52 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 106
# ------------------------------
# f(n) = 61 (Function Score)
# g(n) = 53 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 108
# ------------------------------
# f(n) = 60 (Function Score)
# g(n) = 54 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# search cost: 110
# ------------------------------
# f(n) = 59 (Function Score)
# g(n) = 55 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# search cost: 112
# ------------------------------
# f(n) = 60 (Function Score)
# g(n) = 56 (Current Step Cost)
# p(n) = 4 (Manhattan Distance)
# search cost: 114
# ------------------------------
# f(n) = 61 (Function Score)
# g(n) = 57 (Current Step Cost)
# p(n) = 4 (Manhattan Distance)
# search cost: 116
# ------------------------------
# f(n) = 60 (Function Score)
# g(n) = 58 (Current Step Cost)
# p(n) = 4 (Manhattan Distance)
# search cost: 118
# ------------------------------
# f(n) = 59 (Function Score)
# g(n) = 59 (Current Step Cost)
# p(n) = 2 (Manhattan Distance)
# search cost: 120
# ------------------------------
# ([[['2', '1', '6'], ['*', '4', '8'], ['7', '5', '3']],
#   [['*', '1', '6'], ['2', '4', '8'], ['7', '5', '3']],
#   [['1', '*', '6'], ['2', '4', '8'], ['7', '5', '3']],
#   [['1', '6', '*'], ['2', '4', '8'], ['7', '5', '3']],
#   [['1', '6', '8'], ['2', '4', '*'], ['7', '5', '3']],
#   [['1', '6', '8'], ['2', '*', '4'], ['7', '5', '3']],
#   [['1', '6', '8'], ['*', '2', '4'], ['7', '5', '3']],
#   [['*', '6', '8'], ['1', '2', '4'], ['7', '5', '3']],
#   [['6', '*', '8'], ['1', '2', '4'], ['7', '5', '3']],
#   [['6', '2', '8'], ['1', '*', '4'], ['7', '5', '3']],
#   [['6', '2', '8'], ['*', '1', '4'], ['7', '5', '3']],
#   [['*', '2', '8'], ['6', '1', '4'], ['7', '5', '3']],
#   [['2', '*', '8'], ['6', '1', '4'], ['7', '5', '3']],
#   [['2', '1', '8'], ['6', '*', '4'], ['7', '5', '3']],
#   [['2', '1', '8'], ['*', '6', '4'], ['7', '5', '3']],
#   [['*', '1', '8'], ['2', '6', '4'], ['7', '5', '3']],
#   [['1', '*', '8'], ['2', '6', '4'], ['7', '5', '3']],
#   [['1', '8', '*'], ['2', '6', '4'], ['7', '5', '3']],
#   [['1', '8', '4'], ['2', '6', '*'], ['7', '5', '3']],
#   [['1', '8', '4'], ['2', '*', '6'], ['7', '5', '3']],
#   [['1', '8', '4'], ['*', '2', '6'], ['7', '5', '3']],
#   [['*', '8', '4'], ['1', '2', '6'], ['7', '5', '3']],
#   [['8', '*', '4'], ['1', '2', '6'], ['7', '5', '3']],
#   [['8', '2', '4'], ['1', '*', '6'], ['7', '5', '3']],
#   [['8', '2', '4'], ['1', '6', '*'], ['7', '5', '3']],
#   [['8', '2', '*'], ['1', '6', '4'], ['7', '5', '3']],
#   [['8', '*', '2'], ['1', '6', '4'], ['7', '5', '3']],
#   [['8', '6', '2'], ['1', '*', '4'], ['7', '5', '3']],
#   [['8', '6', '2'], ['*', '1', '4'], ['7', '5', '3']],
#   [['*', '6', '2'], ['8', '1', '4'], ['7', '5', '3']],
#   [['6', '*', '2'], ['8', '1', '4'], ['7', '5', '3']],
#   [['6', '1', '2'], ['8', '*', '4'], ['7', '5', '3']],
#   [['6', '1', '2'], ['*', '8', '4'], ['7', '5', '3']],
#   [['*', '1', '2'], ['6', '8', '4'], ['7', '5', '3']],
#   [['1', '*', '2'], ['6', '8', '4'], ['7', '5', '3']],
#   [['1', '2', '*'], ['6', '8', '4'], ['7', '5', '3']],
#   [['1', '2', '4'], ['6', '8', '*'], ['7', '5', '3']],
#   [['1', '2', '4'], ['6', '*', '8'], ['7', '5', '3']],
#   [['1', '2', '4'], ['*', '6', '8'], ['7', '5', '3']],
#   [['*', '2', '4'], ['1', '6', '8'], ['7', '5', '3']],
#   [['2', '*', '4'], ['1', '6', '8'], ['7', '5', '3']],
#   [['2', '6', '4'], ['1', '*', '8'], ['7', '5', '3']],
#   [['2', '6', '4'], ['1', '8', '*'], ['7', '5', '3']],
#   [['2', '6', '*'], ['1', '8', '4'], ['7', '5', '3']],
#   [['2', '*', '6'], ['1', '8', '4'], ['7', '5', '3']],
#   [['*', '2', '6'], ['1', '8', '4'], ['7', '5', '3']],
#   [['1', '2', '6'], ['*', '8', '4'], ['7', '5', '3']],
#   [['1', '2', '6'], ['8', '*', '4'], ['7', '5', '3']],
#   [['1', '2', '6'], ['8', '4', '*'], ['7', '5', '3']],
#   [['1', '2', '*'], ['8', '4', '6'], ['7', '5', '3']],
#   [['1', '*', '2'], ['8', '4', '6'], ['7', '5', '3']],
#   [['1', '4', '2'], ['8', '*', '6'], ['7', '5', '3']],
#   [['1', '4', '2'], ['8', '6', '*'], ['7', '5', '3']],
#   [['1', '4', '2'], ['8', '6', '3'], ['7', '5', '*']],
#   [['1', '4', '2'], ['8', '6', '3'], ['7', '*', '5']],
#   [['1', '4', '2'], ['8', '*', '3'], ['7', '6', '5']],
#   [['1', '*', '2'], ['8', '4', '3'], ['7', '6', '5']],
#   [['1', '2', '*'], ['8', '4', '3'], ['7', '6', '5']],
#   [['1', '2', '3'], ['8', '4', '*'], ['7', '6', '5']],
#   [['1', '2', '3'], ['8', '*', '4'], ['7', '6', '5']]],
#  60)

# %%
main_function(start_state, end_state, 'nilsson sequence')
# Out:
# f(n) = 57 (Function Score)
# g(n) = 0 (Current Step Cost)
# p(n) = 16 (Manhattan Distance)
# s(n) = 16 (Sequence Score)
# h(n) = 60 (Nilsson Sequence)
# search cost: 2
# ------------------------------
# f(n) = 60 (Function Score)
# g(n) = 1 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 4
# ------------------------------
# f(n) = 59 (Function Score)
# g(n) = 2 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 6
# ------------------------------
# f(n) = 60 (Function Score)
# g(n) = 3 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 8
# ------------------------------
# f(n) = 61 (Function Score)
# g(n) = 4 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 10
# ------------------------------
# f(n) = 62 (Function Score)
# g(n) = 5 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 12
# ------------------------------
# f(n) = 61 (Function Score)
# g(n) = 6 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 14
# ------------------------------
# f(n) = 64 (Function Score)
# g(n) = 7 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 55 (Nilsson Sequence)
# search cost: 16
# ------------------------------
# f(n) = 65 (Function Score)
# g(n) = 8 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 18
# ------------------------------
# f(n) = 68 (Function Score)
# g(n) = 9 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 20
# ------------------------------
# f(n) = 69 (Function Score)
# g(n) = 10 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 22
# ------------------------------
# f(n) = 70 (Function Score)
# g(n) = 11 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 24
# ------------------------------
# f(n) = 69 (Function Score)
# g(n) = 12 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 26
# ------------------------------
# f(n) = 59 (Function Score)
# g(n) = 13 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 28
# ------------------------------
# f(n) = 57 (Function Score)
# g(n) = 14 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# s(n) = 12 (Sequence Score)
# h(n) = 46 (Nilsson Sequence)
# search cost: 30
# ------------------------------
# f(n) = 58 (Function Score)
# g(n) = 15 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 43 (Nilsson Sequence)
# search cost: 32
# ------------------------------
# f(n) = 57 (Function Score)
# g(n) = 16 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 43 (Nilsson Sequence)
# search cost: 34
# ------------------------------
# f(n) = 53 (Function Score)
# g(n) = 17 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 41 (Nilsson Sequence)
# search cost: 36
# ------------------------------
# f(n) = 51 (Function Score)
# g(n) = 18 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# s(n) = 10 (Sequence Score)
# h(n) = 36 (Nilsson Sequence)
# search cost: 38
# ------------------------------
# f(n) = 60 (Function Score)
# g(n) = 19 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# s(n) = 9 (Sequence Score)
# h(n) = 33 (Nilsson Sequence)
# search cost: 40
# ------------------------------
# f(n) = 55 (Function Score)
# g(n) = 20 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 41 (Nilsson Sequence)
# search cost: 42
# ------------------------------
# f(n) = 56 (Function Score)
# g(n) = 21 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# s(n) = 9 (Sequence Score)
# h(n) = 35 (Nilsson Sequence)
# search cost: 44
# ------------------------------
# f(n) = 55 (Function Score)
# g(n) = 22 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# s(n) = 9 (Sequence Score)
# h(n) = 35 (Nilsson Sequence)
# search cost: 46
# ------------------------------
# f(n) = 45 (Function Score)
# g(n) = 23 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# s(n) = 9 (Sequence Score)
# h(n) = 33 (Nilsson Sequence)
# search cost: 48
# ------------------------------
# f(n) = 43 (Function Score)
# g(n) = 24 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# s(n) = 6 (Sequence Score)
# h(n) = 22 (Nilsson Sequence)
# search cost: 50
# ------------------------------
# f(n) = 44 (Function Score)
# g(n) = 25 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# s(n) = 5 (Sequence Score)
# h(n) = 19 (Nilsson Sequence)
# search cost: 52
# ------------------------------
# f(n) = 37 (Function Score)
# g(n) = 26 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# s(n) = 5 (Sequence Score)
# h(n) = 19 (Nilsson Sequence)
# search cost: 54
# ------------------------------
# f(n) = 27 (Function Score)
# g(n) = 27 (Current Step Cost)
# p(n) = 3 (Manhattan Distance)
# s(n) = 3 (Sequence Score)
# h(n) = 11 (Nilsson Sequence)
# search cost: 56
# ------------------------------
# ([[['2', '1', '6'], ['*', '4', '8'], ['7', '5', '3']],
#   [['*', '1', '6'], ['2', '4', '8'], ['7', '5', '3']],
#   [['1', '*', '6'], ['2', '4', '8'], ['7', '5', '3']],
#   [['1', '6', '*'], ['2', '4', '8'], ['7', '5', '3']],
#   [['1', '6', '8'], ['2', '4', '*'], ['7', '5', '3']],
#   [['1', '6', '8'], ['2', '4', '3'], ['7', '5', '*']],
#   [['1', '6', '8'], ['2', '4', '3'], ['7', '*', '5']],
#   [['1', '6', '8'], ['2', '4', '3'], ['*', '7', '5']],
#   [['1', '6', '8'], ['*', '4', '3'], ['2', '7', '5']],
#   [['*', '6', '8'], ['1', '4', '3'], ['2', '7', '5']],
#   [['6', '*', '8'], ['1', '4', '3'], ['2', '7', '5']],
#   [['6', '8', '*'], ['1', '4', '3'], ['2', '7', '5']],
#   [['6', '8', '3'], ['1', '4', '*'], ['2', '7', '5']],
#   [['6', '8', '3'], ['1', '*', '4'], ['2', '7', '5']],
#   [['6', '*', '3'], ['1', '8', '4'], ['2', '7', '5']],
#   [['*', '6', '3'], ['1', '8', '4'], ['2', '7', '5']],
#   [['1', '6', '3'], ['*', '8', '4'], ['2', '7', '5']],
#   [['1', '6', '3'], ['8', '*', '4'], ['2', '7', '5']],
#   [['1', '*', '3'], ['8', '6', '4'], ['2', '7', '5']],
#   [['*', '1', '3'], ['8', '6', '4'], ['2', '7', '5']],
#   [['8', '1', '3'], ['*', '6', '4'], ['2', '7', '5']],
#   [['8', '1', '3'], ['2', '6', '4'], ['*', '7', '5']],
#   [['8', '1', '3'], ['2', '6', '4'], ['7', '*', '5']],
#   [['8', '1', '3'], ['2', '*', '4'], ['7', '6', '5']],
#   [['8', '1', '3'], ['*', '2', '4'], ['7', '6', '5']],
#   [['*', '1', '3'], ['8', '2', '4'], ['7', '6', '5']],
#   [['1', '*', '3'], ['8', '2', '4'], ['7', '6', '5']],
#   [['1', '2', '3'], ['8', '*', '4'], ['7', '6', '5']]],
#  28)

# %%
main_function(start_state, end_state, 'wrong tiles')
# Out:
# f(n) = 7 (Function Score)
# g(n) = 0 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 2
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 1 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 4
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 2 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 6
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 3 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 8
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 4 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 10
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 5 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 12
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 6 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 14
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 7 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 16
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 8 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 18
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 9 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 20
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 10 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 22
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 11 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 24
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 12 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 26
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 13 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 28
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 14 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 30
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 15 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 32
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 16 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 34
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 17 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 36
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 18 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 38
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 19 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 40
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 20 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 42
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 21 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 44
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 22 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 46
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 23 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 48
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 24 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 50
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 25 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 52
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 26 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 54
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 27 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 56
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 28 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 58
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 29 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 60
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 30 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 62
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 31 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 64
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 32 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 66
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 33 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 68
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 34 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 70
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 35 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 72
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 36 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 74
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 37 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 76
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 38 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 78
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 39 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 80
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 40 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 82
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 41 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 84
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 42 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 86
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 43 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 88
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 44 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 90
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 45 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 92
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 46 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 94
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 47 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 96
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 48 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 98
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 49 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 100
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 50 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 102
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 51 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 104
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 52 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 106
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 53 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 108
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 54 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 110
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 55 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 112
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 56 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 114
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 57 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 116
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 58 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 118
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 59 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 120
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 60 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 122
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 61 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 124
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 62 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 126
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 63 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 128
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 64 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 130
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 65 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 132
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 66 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 134
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 67 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 136
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 68 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 138
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 69 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 140
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 70 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 142
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 71 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 144
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 72 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 146
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 73 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 148
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 74 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 150
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 75 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 152
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 76 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 154
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 77 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 156
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 78 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 158
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 79 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 160
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 80 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 162
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 81 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 164
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 82 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 166
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 83 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 168
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 84 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 170
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 85 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 172
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 86 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 174
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 87 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 176
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 88 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 178
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 89 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 180
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 90 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 182
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 91 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 184
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 92 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 186
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 93 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 188
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 94 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 190
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 95 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 192
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 96 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 194
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 97 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 196
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 98 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 198
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 99 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 200
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 100 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 202
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 101 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 204
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 102 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 206
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 103 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 208
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 104 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 210
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 105 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 212
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 106 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 214
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 107 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 216
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 108 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 218
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 109 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 220
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 110 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 222
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 111 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 224
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 112 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 226
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 113 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 228
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 114 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 230
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 115 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 232
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 116 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 234
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 117 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 236
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 118 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 238
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 119 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 240
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 120 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 242
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 121 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 244
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 122 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 246
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 123 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 248
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 124 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 250
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 125 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 252
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 126 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 254
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 127 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 256
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 128 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 258
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 129 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 260
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 130 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 262
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 131 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 264
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 132 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 266
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 133 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 268
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 134 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 270
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 135 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 272
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 136 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 274
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 137 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 276
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 138 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 278
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 139 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 280
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 140 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 282
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 141 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 284
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 142 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 286
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 143 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 288
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 144 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 290
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 145 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 292
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 146 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 294
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 147 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 296
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 148 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 298
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 149 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 300
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 150 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 302
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 151 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 304
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 152 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 306
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 153 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 308
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 154 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 310
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 155 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 312
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 156 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 314
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 157 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 316
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 158 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 318
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 159 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 320
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 160 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 322
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 161 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 324
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 162 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 326
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 163 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 328
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 164 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 330
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 165 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 332
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 166 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 334
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 167 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 336
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 168 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 338
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 169 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 340
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 170 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 342
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 171 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 344
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 172 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 346
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 173 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 348
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 174 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 350
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 175 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 352
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 176 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 354
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 177 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 356
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 178 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 358
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 179 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 360
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 180 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 362
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 181 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 364
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 182 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 366
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 183 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 368
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 184 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 370
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 185 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 372
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 186 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 374
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 187 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 376
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 188 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 378
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 189 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 380
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 190 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 382
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 191 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 384
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 192 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 386
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 193 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 388
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 194 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 390
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 195 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 392
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 196 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 394
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 197 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 396
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 198 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 398
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 199 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 400
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 200 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 402
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 201 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 404
# ------------------------------
# f(n) = 2 (Function Score)
# g(n) = 202 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 406
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 203 (Current Step Cost)
# m(n) = 2 (Wrong Tiles Count)
# search cost: 408
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 204 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 410
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 205 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 412
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 206 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 414
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 207 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 416
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 208 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 418
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 209 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 420
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 210 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 422
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 211 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 424
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 212 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 426
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 213 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 428
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 214 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 430
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 215 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 432
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 216 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 434
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 217 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 436
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 218 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 438
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 219 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 440
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 220 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 442
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 221 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 444
# ------------------------------
# f(n) = 2 (Function Score)
# g(n) = 222 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 446
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 223 (Current Step Cost)
# m(n) = 2 (Wrong Tiles Count)
# search cost: 448
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 224 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 450
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 225 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 452
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 226 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 454
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 227 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 456
# ------------------------------
# f(n) = 2 (Function Score)
# g(n) = 228 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 458
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 229 (Current Step Cost)
# m(n) = 2 (Wrong Tiles Count)
# search cost: 460
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 230 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 462
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 231 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 464
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 232 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 466
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 233 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 468
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 234 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 470
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 235 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 472
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 236 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 474
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 237 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 476
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 238 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 478
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 239 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 480
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 240 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 482
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 241 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 484
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 242 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 486
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 243 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 488
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 244 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 490
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 245 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 492
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 246 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 494
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 247 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 496
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 248 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 498
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 249 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 500
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 250 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 502
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 251 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 504
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 252 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 506
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 253 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 508
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 254 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 510
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 255 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 512
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 256 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 514
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 257 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 516
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 258 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 518
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 259 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 520
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 260 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 522
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 261 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 524
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 262 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 526
# ------------------------------
# f(n) = 3 (Function Score)
# g(n) = 263 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 528
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 264 (Current Step Cost)
# m(n) = 3 (Wrong Tiles Count)
# search cost: 530
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 265 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 532
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 266 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 534
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 267 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 536
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 268 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 538
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 269 (Current Step Cost)
# m(n) = 4 (Wrong Tiles Count)
# search cost: 540
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 270 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 542
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 271 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 544
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 272 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 546
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 273 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 548
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 274 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 550
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 275 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 552
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 276 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 554
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 277 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 556
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 278 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 558
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 279 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 560
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 280 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 562
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 281 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 564
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 282 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 566
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 283 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 568
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 284 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 570
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 285 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 572
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 286 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 574
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 287 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 576
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 288 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 578
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 289 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 580
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 290 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 582
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 291 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 584
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 292 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 586
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 293 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 588
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 294 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 590
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 295 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 592
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 296 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 594
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 297 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 596
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 298 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 598
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 299 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 600
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 300 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 602
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 301 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 604
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 302 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 606
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 303 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 608
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 304 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 610
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 305 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 612
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 306 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 614
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 307 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 616
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 308 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 618
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 309 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 620
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 310 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 622
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 311 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 624
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 312 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 626
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 313 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 628
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 314 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 630
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 315 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 632
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 316 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 634
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 317 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 636
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 318 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 638
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 319 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 640
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 320 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 642
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 321 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 644
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 322 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 646
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 323 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 648
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 324 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 650
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 325 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 652
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 326 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 654
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 327 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 656
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 328 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 658
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 329 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 660
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 330 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 662
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 331 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 664
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 332 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 666
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 333 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 668
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 334 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 670
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 335 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 672
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 336 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 674
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 337 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 676
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 338 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 678
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 339 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 680
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 340 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 682
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 341 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 684
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 342 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 686
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 343 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 688
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 344 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 690
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 345 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 692
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 346 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 694
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 347 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 696
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 348 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 698
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 349 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 700
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 350 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 702
# ------------------------------
# f(n) = 4 (Function Score)
# g(n) = 351 (Current Step Cost)
# m(n) = 5 (Wrong Tiles Count)
# search cost: 704
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 352 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 706
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 353 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 708
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 354 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 710
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 355 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 712
# ------------------------------
# f(n) = 7 (Function Score)
# g(n) = 356 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 714
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 357 (Current Step Cost)
# m(n) = 7 (Wrong Tiles Count)
# search cost: 716
# ------------------------------
# f(n) = 6 (Function Score)
# g(n) = 358 (Current Step Cost)
# m(n) = 6 (Wrong Tiles Count)
# search cost: 718
# ------------------------------
# f(n) = 5 (Function Score)
# g(n) = 359 (Current Step Cost)
# ...
#   [['8', '2', '*'], ['3', '4', '1'], ['7', '6', '5']],
#   [['8', '*', '2'], ['3', '4', '1'], ['7', '6', '5']],
#   [['*', '8', '2'], ['3', '4', '1'], ['7', '6', '5']],
#   [['3', '8', '2'], ['*', '4', '1'], ['7', '6', '5']],
#   [['3', '8', '2'], ['4', '*', '1'], ['7', '6', '5']],
#   [['3', '8', '2'], ['4', '1', '*'], ['7', '6', '5']],
#   [['3', '8', '*'], ['4', '1', '2'], ['7', '6', '5']],
#   [['3', '*', '8'], ['4', '1', '2'], ['7', '6', '5']],
#   [['*', '3', '8'], ['4', '1', '2'], ['7', '6', '5']],
#   [['4', '3', '8'], ['*', '1', '2'], ['7', '6', '5']],
#   [['4', '3', '8'], ['1', '*', '2'], ['7', '6', '5']],
#   [['4', '3', '8'], ['1', '2', '*'], ['7', '6', '5']],
#   [['4', '3', '*'], ['1', '2', '8'], ['7', '6', '5']],
#   [['4', '*', '3'], ['1', '2', '8'], ['7', '6', '5']],
#   [['4', '2', '3'], ['1', '*', '8'], ['7', '6', '5']],
#   [['4', '2', '3'], ['*', '1', '8'], ['7', '6', '5']],
#   [['*', '2', '3'], ['4', '1', '8'], ['7', '6', '5']],
#   [['2', '*', '3'], ['4', '1', '8'], ['7', '6', '5']],
#   [['2', '1', '3'], ['4', '*', '8'], ['7', '6', '5']],
#   [['2', '1', '3'], ['*', '4', '8'], ['7', '6', '5']],
#   [['*', '1', '3'], ['2', '4', '8'], ['7', '6', '5']],
#   [['1', '*', '3'], ['2', '4', '8'], ['7', '6', '5']],
#   [['1', '4', '3'], ['2', '*', '8'], ['7', '6', '5']],
#   [['1', '4', '3'], ['*', '2', '8'], ['7', '6', '5']],
#   [['*', '4', '3'], ['1', '2', '8'], ['7', '6', '5']],
#   [['4', '*', '3'], ['1', '2', '8'], ['7', '6', '5']],
#   [['8', '4', '2'], ['*', '3', '1'], ['7', '6', '5']],
#   [['*', '4', '2'], ['8', '3', '1'], ['7', '6', '5']],
#   [['4', '*', '2'], ['8', '3', '1'], ['7', '6', '5']],
#   [['4', '2', '*'], ['8', '3', '1'], ['7', '6', '5']],
#   [['4', '2', '1'], ['8', '3', '*'], ['7', '6', '5']],
#   [['4', '2', '1'], ['8', '*', '3'], ['7', '6', '5']],
#   [['4', '2', '1'], ['*', '8', '3'], ['7', '6', '5']],
#   [['*', '2', '1'], ['4', '8', '3'], ['7', '6', '5']],
#   [['2', '*', '1'], ['4', '8', '3'], ['7', '6', '5']],
#   [['2', '1', '*'], ['4', '8', '3'], ['7', '6', '5']],
#   [['2', '1', '3'], ['4', '8', '*'], ['7', '6', '5']],
#   [['2', '1', '3'], ['4', '*', '8'], ['7', '6', '5']],
#   [['2', '1', '3'], ['4', '8', '5'], ['7', '*', '6']],
#   [['2', '1', '3'], ['4', '*', '5'], ['7', '8', '6']],
#   [['2', '1', '3'], ['*', '4', '5'], ['7', '8', '6']],
#   [['*', '1', '3'], ['2', '4', '5'], ['7', '8', '6']],
#   [['1', '*', '3'], ['2', '4', '5'], ['7', '8', '6']],
#   [['1', '4', '3'], ['2', '*', '5'], ['7', '8', '6']],
#   [['1', '4', '3'], ['*', '2', '5'], ['7', '8', '6']],
#   [['*', '4', '3'], ['1', '2', '5'], ['7', '8', '6']],
#   [['4', '*', '3'], ['1', '2', '5'], ['7', '8', '6']],
#   [['4', '2', '3'], ['1', '*', '5'], ['7', '8', '6']],
#   [['4', '2', '3'], ['*', '1', '5'], ['7', '8', '6']],
#   [['*', '2', '3'], ['4', '1', '5'], ['7', '8', '6']],
#   [['2', '*', '3'], ['4', '1', '5'], ['7', '8', '6']],
#   [['2', '1', '3'], ['4', '*', '5'], ['7', '8', '6']],
#   [['2', '3', '5'], ['4', '1', '*'], ['7', '8', '6']],
#   [['2', '3', '5'], ['4', '*', '1'], ['7', '8', '6']],
#   [['2', '3', '5'], ['*', '4', '1'], ['7', '8', '6']],
#   [['*', '3', '5'], ['2', '4', '1'], ['7', '8', '6']],
#   [['3', '*', '5'], ['2', '4', '1'], ['7', '8', '6']],
#   [['3', '5', '*'], ['2', '4', '1'], ['7', '8', '6']],
#   [['3', '5', '1'], ['2', '4', '*'], ['7', '8', '6']],
#   [['3', '5', '1'], ['2', '*', '4'], ['7', '8', '6']],
#   [['3', '5', '1'], ['*', '2', '4'], ['7', '8', '6']],
#   [['*', '5', '1'], ['3', '2', '4'], ['7', '8', '6']],
#   [['5', '*', '1'], ['3', '2', '4'], ['7', '8', '6']],
#   [['5', '2', '1'], ['3', '*', '4'], ['7', '8', '6']],
#   [['5', '2', '1'], ['*', '3', '4'], ['7', '8', '6']],
#   [['*', '2', '1'], ['5', '3', '4'], ['7', '8', '6']],
#   [['2', '*', '1'], ['5', '3', '4'], ['7', '8', '6']],
#   [['2', '1', '*'], ['5', '3', '4'], ['7', '8', '6']],
#   [['2', '1', '4'], ['5', '3', '*'], ['7', '8', '6']],
#   [['2', '1', '4'], ['5', '*', '3'], ['7', '8', '6']],
#   [['2', '1', '4'], ['*', '5', '3'], ['7', '8', '6']],
#   [['*', '1', '4'], ['2', '5', '3'], ['7', '8', '6']],
#   [['1', '*', '4'], ['2', '5', '3'], ['7', '8', '6']],
#   [['1', '4', '*'], ['2', '5', '3'], ['7', '8', '6']],
#   [['1', '4', '3'], ['2', '5', '*'], ['7', '8', '6']],
#   [['1', '4', '3'], ['2', '*', '5'], ['7', '8', '6']],
#   [['1', '4', '3'], ['2', '5', '6'], ['7', '*', '8']],
#   [['1', '4', '3'], ['2', '*', '6'], ['7', '5', '8']],
#   [['1', '4', '3'], ['*', '2', '6'], ['7', '5', '8']],
#   [['*', '4', '3'], ['1', '2', '6'], ['7', '5', '8']],
#   [['4', '*', '3'], ['1', '2', '6'], ['7', '5', '8']],
#   [['4', '2', '3'], ['1', '*', '6'], ['7', '5', '8']],
#   [['4', '2', '3'], ['*', '1', '6'], ['7', '5', '8']],
#   [['*', '2', '3'], ['4', '1', '6'], ['7', '5', '8']],
#   [['2', '*', '3'], ['4', '1', '6'], ['7', '5', '8']],
#   [['2', '1', '3'], ['4', '*', '6'], ['7', '5', '8']],
#   [['2', '1', '3'], ['*', '4', '6'], ['7', '5', '8']],
#   [['*', '1', '3'], ['2', '4', '6'], ['7', '5', '8']],
#   [['1', '*', '3'], ['2', '4', '6'], ['7', '5', '8']],
#   [['1', '4', '3'], ['2', '*', '6'], ['7', '5', '8']],
#   [['1', '3', '6'], ['2', '4', '*'], ['7', '5', '8']],
#   [['1', '3', '6'], ['2', '*', '4'], ['7', '5', '8']],
#   [['1', '3', '6'], ['*', '2', '4'], ['7', '5', '8']],
#   [['*', '3', '6'], ['1', '2', '4'], ['7', '5', '8']],
#   [['3', '*', '6'], ['1', '2', '4'], ['7', '5', '8']],
#   [['3', '2', '6'], ['1', '*', '4'], ['7', '5', '8']],
#   [['3', '2', '6'], ['*', '1', '4'], ['7', '5', '8']],
#   [['*', '2', '6'], ['3', '1', '4'], ['7', '5', '8']],
#   [['2', '*', '6'], ['3', '1', '4'], ['7', '5', '8']],
#   [['2', '6', '*'], ['3', '1', '4'], ['7', '5', '8']],
#   [['2', '6', '4'], ['3', '1', '*'], ['7', '5', '8']],
#   [['2', '6', '4'], ['3', '*', '1'], ['7', '5', '8']],
#   [['2', '6', '4'], ['*', '3', '1'], ['7', '5', '8']],
#   [['*', '6', '4'], ['2', '3', '1'], ['7', '5', '8']],
#   [['6', '*', '4'], ['2', '3', '1'], ['7', '5', '8']],
#   [['6', '4', '*'], ['2', '3', '1'], ['7', '5', '8']],
#   [['6', '4', '1'], ['2', '3', '*'], ['7', '5', '8']],
#   [['6', '4', '1'], ['2', '*', '3'], ['7', '5', '8']],
#   [['6', '4', '1'], ['*', '2', '3'], ['7', '5', '8']],
#   [['*', '4', '1'], ['6', '2', '3'], ['7', '5', '8']],
#   [['4', '*', '1'], ['6', '2', '3'], ['7', '5', '8']],
#   [['4', '2', '1'], ['6', '*', '3'], ['7', '5', '8']],
#   [['4', '2', '1'], ['*', '6', '3'], ['7', '5', '8']],
#   [['*', '2', '1'], ['4', '6', '3'], ['7', '5', '8']],
#   [['2', '*', '1'], ['4', '6', '3'], ['7', '5', '8']],
#   [['2', '1', '*'], ['4', '6', '3'], ['7', '5', '8']],
#   [['2', '1', '3'], ['4', '6', '*'], ['7', '5', '8']],
#   [['2', '1', '3'], ['4', '*', '6'], ['7', '5', '8']],
#   [['2', '1', '3'], ['4', '6', '8'], ['7', '*', '5']],
#   [['2', '1', '3'], ['4', '*', '8'], ['7', '6', '5']],
#   [['2', '1', '3'], ['*', '6', '8'], ['4', '7', '5']],
#   [['2', '1', '3'], ['6', '*', '8'], ['4', '7', '5']],
#   [['2', '1', '3'], ['6', '8', '*'], ['4', '7', '5']],
#   [['2', '1', '*'], ['6', '8', '3'], ['4', '7', '5']],
#   [['2', '*', '1'], ['6', '8', '3'], ['4', '7', '5']],
#   [['*', '2', '1'], ['6', '8', '3'], ['4', '7', '5']],
#   [['6', '2', '1'], ['*', '8', '3'], ['4', '7', '5']],
#   [['6', '2', '1'], ['8', '*', '3'], ['4', '7', '5']],
#   [['6', '2', '1'], ['8', '3', '*'], ['4', '7', '5']],
#   [['6', '2', '*'], ['8', '3', '1'], ['4', '7', '5']],
#   [['6', '*', '2'], ['8', '3', '1'], ['4', '7', '5']],
#   [['*', '6', '2'], ['8', '3', '1'], ['4', '7', '5']],
#   [['8', '6', '2'], ['*', '3', '1'], ['4', '7', '5']],
#   [['8', '6', '2'], ['3', '*', '1'], ['4', '7', '5']],
#   [['8', '6', '2'], ['3', '1', '*'], ['4', '7', '5']],
#   [['8', '6', '*'], ['3', '1', '2'], ['4', '7', '5']],
#   [['8', '*', '6'], ['3', '1', '2'], ['4', '7', '5']],
#   [['*', '8', '6'], ['3', '1', '2'], ['4', '7', '5']],
#   [['3', '8', '6'], ['*', '1', '2'], ['4', '7', '5']],
#   [['3', '8', '6'], ['1', '*', '2'], ['4', '7', '5']],
#   [['3', '8', '6'], ['1', '2', '*'], ['4', '7', '5']],
#   [['3', '8', '*'], ['1', '2', '6'], ['4', '7', '5']],
#   [['3', '*', '8'], ['1', '2', '6'], ['4', '7', '5']],
#   [['3', '2', '8'], ['1', '*', '6'], ['4', '7', '5']],
#   [['3', '2', '8'], ['*', '1', '6'], ['4', '7', '5']],
#   [['*', '2', '8'], ['3', '1', '6'], ['4', '7', '5']],
#   [['2', '*', '8'], ['3', '1', '6'], ['4', '7', '5']],
#   [['2', '8', '*'], ['3', '1', '6'], ['4', '7', '5']],
#   [['2', '8', '6'], ['3', '1', '*'], ['4', '7', '5']],
#   [['2', '8', '6'], ['3', '*', '1'], ['4', '7', '5']],
#   [['2', '8', '6'], ['*', '3', '1'], ['4', '7', '5']],
#   [['*', '8', '6'], ['2', '3', '1'], ['4', '7', '5']],
#   [['8', '*', '6'], ['2', '3', '1'], ['4', '7', '5']],
#   [['8', '6', '*'], ['2', '3', '1'], ['4', '7', '5']],
#   [['8', '6', '1'], ['2', '3', '*'], ['4', '7', '5']],
#   [['8', '6', '1'], ['2', '*', '3'], ['4', '7', '5']],
#   [['8', '6', '1'], ['*', '2', '3'], ['4', '7', '5']],
#   [['*', '6', '1'], ['8', '2', '3'], ['4', '7', '5']],
#   [['6', '*', '1'], ['8', '2', '3'], ['4', '7', '5']],
#   [['6', '2', '1'], ['8', '*', '3'], ['4', '7', '5']],
#   [['6', '1', '3'], ['8', '2', '*'], ['4', '7', '5']],
#   [['6', '1', '3'], ['8', '*', '2'], ['4', '7', '5']],
#   [['6', '*', '3'], ['8', '1', '2'], ['4', '7', '5']],
#   [['*', '6', '3'], ['8', '1', '2'], ['4', '7', '5']],
#   [['8', '6', '3'], ['*', '1', '2'], ['4', '7', '5']],
#   [['8', '6', '3'], ['1', '*', '2'], ['4', '7', '5']],
#   [['8', '6', '3'], ['1', '2', '*'], ['4', '7', '5']],
#   [['8', '6', '*'], ['1', '2', '3'], ['4', '7', '5']],
#   [['8', '*', '6'], ['1', '2', '3'], ['4', '7', '5']],
#   [['8', '2', '6'], ['1', '*', '3'], ['4', '7', '5']],
#   [['8', '2', '6'], ['*', '1', '3'], ['4', '7', '5']],
#   [['*', '2', '6'], ['8', '1', '3'], ['4', '7', '5']],
#   [['2', '*', '6'], ['8', '1', '3'], ['4', '7', '5']],
#   [['2', '6', '*'], ['8', '1', '3'], ['4', '7', '5']],
#   [['2', '6', '3'], ['8', '1', '*'], ['4', '7', '5']],
#   [['2', '6', '3'], ['8', '*', '1'], ['4', '7', '5']],
#   [['2', '*', '3'], ['8', '6', '1'], ['4', '7', '5']],
#   [['*', '2', '3'], ['8', '6', '1'], ['4', '7', '5']],
#   [['8', '2', '3'], ['*', '6', '1'], ['4', '7', '5']],
#   [['8', '2', '3'], ['6', '*', '1'], ['4', '7', '5']],
#   [['8', '2', '3'], ['6', '1', '*'], ['4', '7', '5']],
#   [['8', '2', '*'], ['6', '1', '3'], ['4', '7', '5']],
#   [['8', '*', '2'], ['6', '1', '3'], ['4', '7', '5']],
#   [['*', '8', '2'], ['6', '1', '3'], ['4', '7', '5']],
#   [['6', '8', '2'], ['*', '1', '3'], ['4', '7', '5']],
#   [['6', '8', '2'], ['1', '*', '3'], ['4', '7', '5']],
#   [['6', '8', '2'], ['1', '3', '*'], ['4', '7', '5']],
#   [['6', '8', '*'], ['1', '3', '2'], ['4', '7', '5']],
#   [['6', '*', '8'], ['1', '3', '2'], ['4', '7', '5']],
#   [['*', '6', '8'], ['1', '3', '2'], ['4', '7', '5']],
#   [['1', '6', '8'], ['*', '3', '2'], ['4', '7', '5']],
#   [['1', '6', '8'], ['3', '*', '2'], ['4', '7', '5']],
#   [['1', '6', '8'], ['3', '2', '*'], ['4', '7', '5']],
#   [['1', '6', '*'], ['3', '2', '8'], ['4', '7', '5']],
#   [['1', '*', '6'], ['3', '2', '8'], ['4', '7', '5']],
#   [['1', '2', '6'], ['3', '*', '8'], ['4', '7', '5']],
#   [['1', '2', '6'], ['*', '3', '8'], ['4', '7', '5']],
#   [['1', '2', '6'], ['4', '3', '8'], ['*', '7', '5']],
#   [['1', '2', '6'], ['4', '3', '8'], ['7', '*', '5']],
#   [['1', '2', '6'], ['4', '*', '8'], ['7', '3', '5']],
#   [['1', '2', '6'], ['*', '4', '8'], ['7', '3', '5']],
#   [['*', '2', '6'], ['1', '4', '8'], ['7', '3', '5']],
#   [['2', '*', '6'], ['1', '4', '8'], ['7', '3', '5']],
#   [['2', '6', '*'], ['1', '4', '8'], ['7', '3', '5']],
#   [['2', '6', '8'], ['1', '4', '*'], ['7', '3', '5']],
#   [['2', '6', '8'], ['1', '*', '4'], ['7', '3', '5']],
#   [['2', '6', '8'], ['*', '1', '4'], ['7', '3', '5']],
#   [['*', '6', '8'], ['2', '1', '4'], ['7', '3', '5']],
#   [['6', '*', '8'], ['2', '1', '4'], ['7', '3', '5']],
#   [['6', '8', '*'], ['2', '1', '4'], ['7', '3', '5']],
#   [['6', '8', '4'], ['2', '1', '*'], ['7', '3', '5']],
#   [['6', '8', '4'], ['2', '*', '1'], ['7', '3', '5']],
#   [['6', '8', '4'], ['*', '2', '1'], ['7', '3', '5']],
#   [['*', '8', '4'], ['6', '2', '1'], ['7', '3', '5']],
#   [['8', '*', '4'], ['6', '2', '1'], ['7', '3', '5']],
#   [['8', '2', '4'], ['6', '*', '1'], ['7', '3', '5']],
#   [['8', '2', '4'], ['*', '6', '1'], ['7', '3', '5']],
#   [['*', '2', '4'], ['8', '6', '1'], ['7', '3', '5']],
#   [['2', '*', '4'], ['8', '6', '1'], ['7', '3', '5']],
#   [['2', '4', '*'], ['8', '6', '1'], ['7', '3', '5']],
#   [['2', '4', '1'], ['8', '6', '*'], ['7', '3', '5']],
#   [['2', '4', '1'], ['8', '*', '6'], ['7', '3', '5']],
#   [['2', '*', '1'], ['8', '4', '6'], ['7', '3', '5']],
#   [['*', '2', '1'], ['8', '4', '6'], ['7', '3', '5']],
#   [['8', '2', '1'], ['*', '4', '6'], ['7', '3', '5']],
#   [['8', '2', '1'], ['4', '*', '6'], ['7', '3', '5']],
#   [['8', '2', '1'], ['4', '6', '*'], ['7', '3', '5']],
#   [['8', '2', '*'], ['4', '6', '1'], ['7', '3', '5']],
#   [['8', '*', '2'], ['4', '6', '1'], ['7', '3', '5']],
#   [['*', '8', '2'], ['4', '6', '1'], ['7', '3', '5']],
#   [['4', '8', '2'], ['*', '6', '1'], ['7', '3', '5']],
#   [['4', '8', '2'], ['6', '*', '1'], ['7', '3', '5']],
#   [['4', '8', '2'], ['6', '1', '*'], ['7', '3', '5']],
#   [['4', '8', '*'], ['6', '1', '2'], ['7', '3', '5']],
#   [['4', '*', '8'], ['6', '1', '2'], ['7', '3', '5']],
#   [['*', '4', '8'], ['6', '1', '2'], ['7', '3', '5']],
#   [['6', '4', '8'], ['*', '1', '2'], ['7', '3', '5']],
#   [['6', '4', '8'], ['1', '*', '2'], ['7', '3', '5']],
#   [['6', '4', '8'], ['1', '2', '*'], ['7', '3', '5']],
#   [['6', '4', '*'], ['1', '2', '8'], ['7', '3', '5']],
#   [['6', '*', '4'], ['1', '2', '8'], ['7', '3', '5']],
#   [['6', '2', '4'], ['1', '*', '8'], ['7', '3', '5']],
#   [['6', '2', '4'], ['*', '1', '8'], ['7', '3', '5']],
#   [['*', '2', '4'], ['6', '1', '8'], ['7', '3', '5']],
#   [['2', '*', '4'], ['6', '1', '8'], ['7', '3', '5']],
#   [['2', '4', '*'], ['6', '1', '8'], ['7', '3', '5']],
#   [['2', '4', '8'], ['6', '1', '*'], ['7', '3', '5']],
#   [['2', '4', '8'], ['6', '*', '1'], ['7', '3', '5']],
#   [['2', '4', '8'], ['*', '6', '1'], ['7', '3', '5']],
#   [['*', '4', '8'], ['2', '6', '1'], ['7', '3', '5']],
#   [['4', '*', '8'], ['2', '6', '1'], ['7', '3', '5']],
#   [['4', '8', '*'], ['2', '6', '1'], ['7', '3', '5']],
#   [['4', '8', '1'], ['2', '6', '*'], ['7', '3', '5']],
#   [['4', '8', '1'], ['2', '*', '6'], ['7', '3', '5']],
#   [['4', '8', '1'], ['*', '2', '6'], ['7', '3', '5']],
#   [['*', '8', '1'], ['4', '2', '6'], ['7', '3', '5']],
#   [['8', '*', '1'], ['4', '2', '6'], ['7', '3', '5']],
#   [['8', '2', '1'], ['4', '*', '6'], ['7', '3', '5']],
#   [['8', '1', '6'], ['4', '2', '*'], ['7', '3', '5']],
#   [['8', '1', '6'], ['4', '*', '2'], ['7', '3', '5']],
#   [['8', '1', '6'], ['*', '4', '2'], ['7', '3', '5']],
#   [['*', '1', '6'], ['8', '4', '2'], ['7', '3', '5']],
#   [['1', '*', '6'], ['8', '4', '2'], ['7', '3', '5']],
#   [['1', '6', '*'], ['8', '4', '2'], ['7', '3', '5']],
#   [['1', '6', '2'], ['8', '4', '*'], ['7', '3', '5']],
#   [['1', '6', '2'], ['8', '*', '4'], ['7', '3', '5']],
#   [['1', '*', '2'], ['8', '6', '4'], ['7', '3', '5']],
#   [['1', '2', '*'], ['8', '6', '4'], ['7', '3', '5']],
#   [['1', '2', '4'], ['8', '6', '*'], ['7', '3', '5']],
#   [['1', '2', '4'], ['8', '*', '6'], ['7', '3', '5']],
#   [['1', '2', '4'], ['8', '3', '6'], ['7', '*', '5']],
#   [['1', '2', '4'], ['8', '3', '6'], ['*', '7', '5']],
#   [['1', '2', '4'], ['*', '3', '6'], ['8', '7', '5']],
#   [['1', '2', '4'], ['3', '*', '6'], ['8', '7', '5']],
#   [['1', '2', '4'], ['3', '6', '*'], ['8', '7', '5']],
#   [['1', '2', '*'], ['3', '6', '4'], ['8', '7', '5']],
#   [['1', '*', '2'], ['3', '6', '4'], ['8', '7', '5']],
#   [['1', '6', '2'], ['3', '*', '4'], ['8', '7', '5']],
#   [['1', '6', '2'], ['*', '3', '4'], ['8', '7', '5']],
#   [['1', '6', '2'], ['8', '3', '4'], ['*', '7', '5']],
#   [['1', '6', '2'], ['8', '3', '4'], ['7', '*', '5']],
#   [['1', '6', '2'], ['8', '*', '4'], ['7', '3', '5']],
#   [['1', '6', '2'], ['8', '3', '*'], ['7', '5', '4']],
#   [['1', '6', '2'], ['8', '*', '3'], ['7', '5', '4']],
#   [['1', '*', '2'], ['8', '6', '3'], ['7', '5', '4']],
#   [['1', '2', '*'], ['8', '6', '3'], ['7', '5', '4']],
#   [['1', '2', '3'], ['8', '6', '*'], ['7', '5', '4']],
#   [['1', '2', '3'], ['8', '6', '4'], ['7', '5', '*']],
#   [['1', '2', '3'], ['8', '6', '4'], ['7', '*', '5']],
#   [['1', '2', '3'], ['8', '*', '4'], ['7', '6', '5']]],
#  522)
